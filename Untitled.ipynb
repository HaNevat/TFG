# %%
import csv
reader = csv.reader(open('id_trackuri_filter.csv', 'r'))
d = {v:k for (k,v) in reader}

# %%
d
# Out:
# {'track_uri': 'id',
#  '0UaMYEvWZi0ZqiDOoHU3YI': '0',
#  '6I9VzXrHxO9rA9A5euc8Ak': '1',
#  '0WqIKmW4BTrj3eJFmnCKMv': '2',
#  '1AWQoqb9bSvzTjaLralEkT': '3',
#  '1lzr43nnXAijIGYnCT8M8H': '4',
#  '0XUfyU2QviPAs6bxSpXYG4': '5',
#  '68vgtRHr7iZHpzGpon6Jlo': '6',
#  '3BxWKCI06eQ5Od8TY2JBeA': '7',
#  '7H6ev70Weq6DdpZyyTmUXk': '8',
#  '2PpruBYCo4H7WOBJ7Q2EwM': '9',
#  '2gam98EZKrF9XuOkU13ApN': '10',
#  '4Y45aqo9QMa57rDsAJv40A': '11',
#  '1HwpWwa6bnqqRhK8agG4RS': '12',
#  '20ORwCJusz4KS2PbTPVNKo': '13',
#  '7k6IzwMGpxnRghE7YosnXT': '14',
#  '1Bv0Yl01xBDZD4OQP93fyl': '15',
#  '4omisSlTk6Dsq2iQD7MA07': '16',
#  '7xYnUQigPoIDAMPVK79NEq': '17',
#  '6d8A5sAx9TfdeseDvfWNHd': '18',
#  '4pmc2AxSEq6g7hPVlJCPyP': '19',
#  '215JYyyUnrJ98NK3KEwu6d': '20',
#  '0uqPG793dkDDN7sCUJJIVC': '21',
#  '19Js5ypV6JKn4DMExHQbGc': '22',
#  '1JURww012QnWAw0zZXi6Aa': '23',
#  '7DFnq8FYhHMCylykf6ZCxA': '24',
#  '1TfAhjzRBWzYZ8IdUV3igl': '25',
#  '1Y4ZdPOOgCUhBcKZOrUFiS': '26',
#  '6MjljecHzHelUDismyKkba': '27',
# ...
